# %% [markdown]
# <a href="https://colab.research.google.com/github/crmtarget/bigdata201901/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
hello = tf.constant("hello World")
sess = tf.Session()

# %%
print(sess.run(hello))
print("안녕하세요")
# Out:
# b'hello World'
# 안녕하세요

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 10 , 0.1)
y = np. sin(x)
plt.plot(x, y)
plt.show()

# %%
t= np.arange(0, 12, 0.01)

# %%
y = np. sin(t)
z = np.cos(t)

# %%
plt.figure(figsize=(10,6))
plt.plot(t, y, label='sin', lw=10)
plt.plot(t, z,'gs', label='cos', lw=1)
plt.legend()

plt.grid()

plt.xlabel('time')
plt.ylabel('value')
plt.title('my graph!!')

plt.show()

# %%
t2 = np.arange(0, 5, 0.5)

# %%
plt.figure(figsize=(10,6))

plt.plot(t2, t2, 'r--')
plt.plot(t2, t2*2, 'bs')
plt.plot(t2, t2*3, 'g^')
plt.plot(t2, t2*4, color = 'pink', linestyle= 'dashed', marker = 'o')
plt.show()

# %%
s1 = np.random.normal(loc=0, scale=1, size=1000)
s2 = np.random.normal(loc=5, scale=0.5, size=1000)
s3 = np.random.normal(loc=10, scale=2, size=1000)

# %%
plt.figure(figsize=(10,6))
plt.plot(s1, label='s1')
plt.plot(s2, label='s2')
plt.plot(s3, label='s3')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.boxplot((s1,s2,s3))
plt.show
# Out:
# <function matplotlib.pyplot.show>
